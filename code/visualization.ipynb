# %%
weather = pd.read_csv('../data/weather.csv')
train = pd.read_csv('../data/train.csv')

# %%
weather_train = weather[:8968] # 2013년 3월 31일가지의 weather data
train_new = train[0:2255853] # 2013년 3월 31일까지의 units

# %%
weather_train_1 = weather_train[weather_train['station_nbr'] == 1] #station1의 train set 날씨
weather_train_1.reset_index(drop = True, inplace = True)

# %%
train_new_1 = train_new[train_new['store_nbr'] == 1] # store_nbr 1의 units

# %%
temp = pd.merge(weather_train_1, train_new_1)
temp
# Out:
#        station_nbr        date tmax tmin tavg depart dewpoint wetbulb heat  \
# 0                1  2012-01-01   52   31   42      M       36      40   23
# 1                1  2012-01-01   52   31   42      M       36      40   23
# 2                1  2012-01-01   52   31   42      M       36      40   23
# 3                1  2012-01-01   52   31   42      M       36      40   23
# 4                1  2012-01-01   52   31   42      M       36      40   23
# 5                1  2012-01-01   52   31   42      M       36      40   23
# 6                1  2012-01-01   52   31   42      M       36      40   23
# 7                1  2012-01-01   52   31   42      M       36      40   23
# 8                1  2012-01-01   52   31   42      M       36      40   23
# 9                1  2012-01-01   52   31   42      M       36      40   23
# 10               1  2012-01-01   52   31   42      M       36      40   23
# ...

# %%
train_new_1
# Out:
#                date  store_nbr  item_nbr  units
# 0        2012-01-01          1         1      0
# 1        2012-01-01          1         2      0
# 2        2012-01-01          1         3      0
# 3        2012-01-01          1         4      0
# 4        2012-01-01          1         5      0
# 5        2012-01-01          1         6      0
# 6        2012-01-01          1         7      0
# 7        2012-01-01          1         8      0
# 8        2012-01-01          1         9     29
# 9        2012-01-01          1        10      0
# 10       2012-01-01          1        11      0
# 11       2012-01-01          1        12      0
# 12       2012-01-01          1        13      0
# 13       2012-01-01          1        14      0
# 14       2012-01-01          1        15      0
# 15       2012-01-01          1        16      0
# 16       2012-01-01          1        17      0
# 17       2012-01-01          1        18      0
# 18       2012-01-01          1        19      0
# ...
