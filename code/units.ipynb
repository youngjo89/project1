# %%
train = pd.read_csv('../data/train.csv')

# %%
train_new = train[0:2255853] # 3월 31일까지의 units

# %%
train_new
# Out:
#                date  store_nbr  item_nbr  units
# 0        2012-01-01          1         1      0
# 1        2012-01-01          1         2      0
# 2        2012-01-01          1         3      0
# 3        2012-01-01          1         4      0
# 4        2012-01-01          1         5      0
# 5        2012-01-01          1         6      0
# 6        2012-01-01          1         7      0
# 7        2012-01-01          1         8      0
# 8        2012-01-01          1         9     29
# 9        2012-01-01          1        10      0
# 10       2012-01-01          1        11      0
# 11       2012-01-01          1        12      0
# 12       2012-01-01          1        13      0
# 13       2012-01-01          1        14      0
# 14       2012-01-01          1        15      0
# 15       2012-01-01          1        16      0
# 16       2012-01-01          1        17      0
# 17       2012-01-01          1        18      0
# 18       2012-01-01          1        19      0
# ...

# %%
train_new_1 = train_new[train_new['store_nbr'] == 1]
train_new_1
# Out:
#                date  store_nbr  item_nbr  units
# 0        2012-01-01          1         1      0
# 1        2012-01-01          1         2      0
# 2        2012-01-01          1         3      0
# 3        2012-01-01          1         4      0
# 4        2012-01-01          1         5      0
# 5        2012-01-01          1         6      0
# 6        2012-01-01          1         7      0
# 7        2012-01-01          1         8      0
# 8        2012-01-01          1         9     29
# 9        2012-01-01          1        10      0
# 10       2012-01-01          1        11      0
# 11       2012-01-01          1        12      0
# 12       2012-01-01          1        13      0
# 13       2012-01-01          1        14      0
# 14       2012-01-01          1        15      0
# 15       2012-01-01          1        16      0
# 16       2012-01-01          1        17      0
# 17       2012-01-01          1        18      0
# 18       2012-01-01          1        19      0
# ...
